# %%
import os

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pyranges
import plotly.graph_objects as go
import plotly.express as px
from scipy.stats import kruskal
from statsmodels.stats.multitest import fdrcorrection


from zhunt_wrapper import alanrun

# %%
# Plots stuff
sns.set()
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
pd.options.plotting.backend = "matplotlib"

# %% [markdown]
# # Run ZHunt

# %%
sequences_df = pd.read_csv('summary.csv')
sequences_df['date'] = pd.to_datetime(sequences_df['date'])
sequences_df
# Out:
#       accession     strain       date acc_date  offset
# 0    MW883202.1    epsilon 2020-10-15        y      18
# 1    MW453103.1       zeta 2020-12-24        y      69
# 2    MW560924.1        eta 2021-01-17        y      50
# 3    MZ681419.1       iota 2020-12-11        y      18
# 4    MW598419.1       beta 2021-01-14        y      73
# 5    MZ275289.1     lambda 2021-01-30        y      24
# 6    MZ555270.1      theta 2021-06-22        y       0
# 7    MZ169911.1      gamma 2021-02-19        y      73
# 8    OD920331.1      alpha 2020-12-11        y      18
# 9    MZ359841.1      delta 2021-04-22        y      22
# 10   MZ702637.1      kappa 2021-04-08        y      22
# 11  NC_045512.2  reference 2019-12-01        y      73
# 12  NC_004718.3   sars2003 2003-04-14        y       0

# %%
z_hunt_results = {}
for _, row in sequences_df[['strain', 'offset']].iterrows():
    strain_name, offset = row.loc['strain'], row.loc['offset']
    with open(f'fasta/{strain_name}.fasta', 'r') as tmp_fasta:
        z_hunt_results[strain_name] = alanrun(''.join(tmp_fasta.readlines()[1:]).replace('\n', '')[offset:],)
# Out:
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1f1994b0
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1f1994b0
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1f1994b0.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1f1994b0.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1f1994b0
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp_d9yd3mx
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp_d9yd3mx
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp_d9yd3mx.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp_d9yd3mx.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp_d9yd3mx
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvvkag2og
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvvkag2og
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvvkag2og.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvvkag2og.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvvkag2og
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9bavi52k
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9bavi52k
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9bavi52k.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9bavi52k.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9bavi52k
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpchy2kqt8
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpchy2kqt8
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpchy2kqt8.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpchy2kqt8.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpchy2kqt8
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpd0zj8pms
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpd0zj8pms
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpd0zj8pms.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpd0zj8pms.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpd0zj8pms
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpoggynoo5
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpoggynoo5
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpoggynoo5.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpoggynoo5.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpoggynoo5
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpfy50z95t
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpfy50z95t
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpfy50z95t.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpfy50z95t.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpfy50z95t
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpf1r1zjbf
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpf1r1zjbf
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpf1r1zjbf.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpf1r1zjbf.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpf1r1zjbf
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvv1bv9t0
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvv1bv9t0
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvv1bv9t0.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvv1bv9t0.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvv1bv9t0
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp854qwq_l
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp854qwq_l
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp854qwq_l.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp854qwq_l.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp854qwq_l
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9pkumjxd
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9pkumjxd
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9pkumjxd.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9pkumjxd.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp9pkumjxd
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpbicpvpvl
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpbicpvpvl
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpbicpvpvl.Z-SCORE
#
#  run time=1 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpbicpvpvl.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpbicpvpvl
# inputting sequence

# %%
z_hunt_results['reference']
# Out:
#        Start    End  nu-1    nu-2    nu-3   Z-Score          Sequence  \
# 0          1     17    16  29.408  18.645  2.155155  actttaaaatctgtgt
# 1          2     18    16  27.108  19.508  5.727038  ctttaaaatctgtgtg
# 2          3     19    16  27.977  24.354  3.719740  tttaaaatctgtgtgg
# 3          4     18    14  26.645  22.761  7.444844    ttaaaatctgtgtg
# 4          5     19    14  27.601  27.189  4.440742    taaaatctgtgtgg
# ...      ...    ...   ...     ...     ...       ...               ...
# 29825  29826  29838    12  38.536  15.203  0.000546      aaaaaactttaa
# 29826  29827  29839    12  35.330   8.624  0.018446      aaaaactttaaa
# 29827  29828  29844    16  36.050   7.037  0.009348  aaaactttaaaatctg
# 29828  29829  29845    16  33.207  11.463  0.095727  aaactttaaaatctgt
# 29829  29830  29846    16  30.734  10.595  0.345587  aactttaaaatctgtg
#
#            Conformation
# 0      SAASASSASASASASA
# 1      ASASASASASASASAS
# 2      ASASSASASASASASA
# 3        ASASASASASASAS
# 4        ASSASASASASASA
# ...                 ...
# 29825      SASASASASASA
# 29826      SASASAASASAS
# 29827  ASASASASASASASAS
# 29828  SASAASASSASASASA
# 29829  ASASASASASASASAS
#
# [29830 rows x 8 columns]

# %%
tmp_df = z_hunt_results['reference'].copy()
tmp_df['Chromosome'] = 0

pyranges.PyRanges(tmp_df)
# Out:
# +-----------+-----------+-----------+-------------+-------------+-------+
# | Start     | End       | nu-1      | nu-2        | nu-3        | +4    |
# | (int32)   | (int32)   | (int64)   | (float64)   | (float64)   | ...   |
# |-----------+-----------+-----------+-------------+-------------+-------|
# | 1         | 17        | 16        | 29.408      | 18.645      | ...   |
# | 2         | 18        | 16        | 27.108      | 19.508      | ...   |
# | 3         | 19        | 16        | 27.977      | 24.354      | ...   |
# | 4         | 18        | 14        | 26.645      | 22.761      | ...   |
# | ...       | ...       | ...       | ...         | ...         | ...   |
# | 29827     | 29839     | 12        | 35.33       | 8.624       | ...   |
# | 29828     | 29844     | 16        | 36.05       | 7.037       | ...   |
# | 29829     | 29845     | 16        | 33.207      | 11.463      | ...   |
# | 29830     | 29846     | 16        | 30.734      | 10.595      | ...   |
# +-----------+-----------+-----------+-------------+-------------+-------+
# Unstranded PyRanges object has 29,830 rows and 9 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 4 hidden columns: Z-Score, Sequence, Conformation, Chromosome

# %%
analysis_df = sequences_df.copy()
analysis_df['mean_zscore'] = analysis_df['strain'].map(lambda strain: z_hunt_results[strain]['Z-Score'].mean())
analysis_df['median_zscore'] = analysis_df['strain'].map(lambda strain: z_hunt_results[strain]['Z-Score'].median())
analysis_df
# Out:
#       accession     strain       date acc_date  offset  mean_zscore  \
# 0    MW883202.1    epsilon 2020-10-15        y      18     6.101679
# 1    MW453103.1       zeta 2020-12-24        y      69     6.090076
# 2    MW560924.1        eta 2021-01-17        y      50     6.096778
# 3    MZ681419.1       iota 2020-12-11        y      18     6.108547
# 4    MW598419.1       beta 2021-01-14        y      73     6.062191
# 5    MZ275289.1     lambda 2021-01-30        y      24     6.101221
# 6    MZ555270.1      theta 2021-06-22        y       0     6.118544
# 7    MZ169911.1      gamma 2021-02-19        y      73     6.094822
# 8    OD920331.1      alpha 2020-12-11        y      18     6.124350
# 9    MZ359841.1      delta 2021-04-22        y      22     6.104658
# 10   MZ702637.1      kappa 2021-04-08        y      22     6.115935
# 11  NC_045512.2  reference 2019-12-01        y      73     6.099432
# 12  NC_004718.3   sars2003 2003-04-14        y       0    73.605367
#
#     median_zscore
# 0        0.384964
# 1        0.383850
# 2        0.385736
# 3        0.384450
# 4        0.383978
# 5        0.385136
# 6        0.384407
# 7        0.385865
# 8        0.384278
# 9        0.384621
# 10       0.386423
# 11       0.384793
# 12       0.436941

# %%
analysis_df = analysis_df[analysis_df['strain']!='sars2003']

# %% [markdown]
# # Plot Mean & Median scores

# %%
METRIC = 'mean_zscore'

ax = analysis_df.plot(x='date', y=METRIC,)
analysis_df.plot(ax=ax, x='date', y=METRIC, style='o')
for index, (_, row) in enumerate(analysis_df.iterrows()):
    ax.annotate(row.strain, (row.date, row[METRIC]), xytext=(10,10), textcoords='offset points')

plt.show()

# %%
METRIC = 'median_zscore'

ax = analysis_df.plot(x='date', y=METRIC,)
analysis_df.plot(ax=ax, x='date', y=METRIC, style='o')
for index, (_, row) in enumerate(analysis_df.iterrows()):
    ax.annotate(row.strain, (row.date, row[METRIC]), xytext=(10,10), textcoords='offset points')

plt.show()

# %% [markdown]
# # Split Zscores by bins:

# %%
def get_bins_borders(bin_size, seq_size):
    return np.arange(0, seq_size + bin_size - 1, bin_size / 2, dtype=int,)  # Include right border

# %%
bin_borders_r = get_bins_borders(100, 31000)
bin_ranges = list(zip(bin_borders_r[:-2], bin_borders_r[2:]))
def process_sequence_zscores(strain, zscores_df, bin_ranges):
    bins_stats = []
    
    tmp_df = zscores_df.copy()
    tmp_df['Chromosome'] = 0
    ranges = pyranges.PyRanges(tmp_df)
    
    for range_ in bin_ranges:
        intersections_df = ranges.intersect(
            pyranges.PyRanges(
                starts=[range_[0]], ends=[range_[1]], chromosomes=[0]
            )  # Chromosomes param added as a workaround for non-chromosome data
        ).df
        if intersections_df.empty:
            bins_stats.append(
                dict(
                    strain=strain,
                    Start=range_[0],
                    End=range_[1],
                    mean=0,
                    median=0,
                    count=0,
                    scores_sum=0,
                    scores=[],
                )
            )
            continue
        bins_stats.append(
            dict(
                strain=strain,
                Start=range_[0],
                End=range_[1],
                mean=intersections_df['Z-Score'].mean(),
                median=intersections_df['Z-Score'].median(),
                count=intersections_df.shape[0],
                scores_sum=intersections_df['Z-Score'].sum(),
                scores=intersections_df['Z-Score'].tolist(),
            )
        )
    result_df = pd.DataFrame(bins_stats)
    return result_df

# %%
bins_stats = []
for strain, zscore_df in z_hunt_results.items():
    bins_stats.append(process_sequence_zscores(strain, zscore_df, bin_ranges))
res_df = pd.concat(bins_stats)
res_df
# Out:
#         strain  Start    End       mean    median  count   scores_sum  \
# 0      epsilon      0    100  16.103566  4.111587     99  1594.253077
# 1      epsilon     50    150  13.420385  3.567837    115  1543.344238
# 2      epsilon    100    200   6.036140  3.484244    112   676.047736
# 3      epsilon    150    250   8.365994  2.884163    112   936.991380
# 4      epsilon    200    300  23.742343  3.050722    115  2730.369421
# ..         ...    ...    ...        ...       ...    ...          ...
# 615  reference  30750  30850   0.000000  0.000000      0     0.000000
# 616  reference  30800  30900   0.000000  0.000000      0     0.000000
# 617  reference  30850  30950   0.000000  0.000000      0     0.000000
# 618  reference  30900  31000   0.000000  0.000000      0     0.000000
# 619  reference  30950  31050   0.000000  0.000000      0     0.000000
#
#                                                 scores
# 0    [0.3455873, 2.155155, 5.727038, 3.71974, 7.444...
# 1    [4.305679, 27.01089, 24.40299, 164.8262, 84.60...
# 2    [5.111722, 5.208544, 5.158997, 0.4621576, 2.07...
# 3    [4.06097, 2.024518, 4.792708, 2.135857, 0.4381...
# 4    [0.1332698, 0.1451564, 0.198011, 0.2180017, 0....
# ..                                                 ...
# 615                                                 []
# 616                                                 []
# 617                                                 []
# 618                                                 []
# 619                                                 []
#
# [7440 rows x 8 columns]

# %%
combined_scores_df = pd.concat(z_hunt_results.values())

combined_scores = []
for strain, _df in z_hunt_results.items():
    df = _df.copy()
    df['strain'] = strain
    combined_scores.append(df)

combined_scores_df = combined_scores_df[combined_scores_df['strain']!='sars2003']
combined_scores_df = pd.concat(combined_scores)

# %%
bin_borders_r = get_bins_borders(100, 31000)
bin_ranges = list(zip(bin_borders_r[:-2], bin_borders_r[2:]))
def get_zscores_by_ranges(combined_scores_df, bin_ranges):
    bins_stats = []
    
    tmp_df = combined_scores_df.copy()
    tmp_df['Chromosome'] = 0
    ranges = pyranges.PyRanges(tmp_df)
    
    for range_ in bin_ranges:
        intersections_df = ranges.intersect(
            pyranges.PyRanges(
                starts=[range_[0]], ends=[range_[1]], chromosomes=[0]
            )  # Chromosomes param added as a workaround for non-chromosome data
        ).df
        intersections_df['Bin_Start'] = range_[0]
        intersections_df['Bin_End'] = range_[1]
        if not intersections_df.empty:
            statistic, pval = kruskal(*intersections_df.groupby('strain')['Z-Score'].apply(list))
            intersections_df['Bin_Start'] = range_[0]
            intersections_df['Bin_End'] = range_[1]
            bins_stats.append({
                'Start': range_[0],
                'End': range_[1],
                'pval': pval,
                'statistic': statistic,
            })
        else:
            bins_stats.append({
                'Start': range_[0],
                'End': range_[1],
                'pval': 1,
                'statistic': 0,
            })
    result_df = pd.DataFrame(bins_stats)
    return result_df


stats_df = get_zscores_by_ranges(combined_scores_df, bin_ranges)
stats_df['P_val_adjusted'] = fdrcorrection(stats_df.pval)[1]
stats_df
# Out:
#      Start    End      pval  statistic  P_val_adjusted
# 0        0    100  0.999999   0.455455             1.0
# 1       50    150  0.998923   1.862632             1.0
# 2      100    200  0.995490   2.543514             1.0
# 3      150    250  1.000000   0.111295             1.0
# 4      200    300  1.000000   0.082547             1.0
# ..     ...    ...       ...        ...             ...
# 615  30750  30850  1.000000   0.000000             1.0
# 616  30800  30900  1.000000   0.000000             1.0
# 617  30850  30950  1.000000   0.000000             1.0
# 618  30900  31000  1.000000   0.000000             1.0
# 619  30950  31050  1.000000   0.000000             1.0
#
# [620 rows x 5 columns]

# %%
stats_df[stats_df['P_val_adjusted']<=0.05]
# Out:
#      Start    End          pval  statistic  P_val_adjusted
# 447  22350  22450  3.285507e-06  45.960673        0.000800
# 456  22800  22900  3.868702e-06  45.558624        0.000800
# 459  22950  23050  4.580231e-04  33.371090        0.040568
# 485  24250  24350  2.278536e-04  35.220780        0.028254
# 570  28500  28600  9.130508e-06  43.432547        0.001415
# 594  29700  29800  4.243379e-04  33.574940        0.040568
# 595  29750  29850  6.220083e-08  51.266169        0.000039

# %%
METRIC = 'mean'
fig, ax = plt.subplots()

for name, group in res_df.groupby('strain'):
    group.plot(ax=ax, x='Start', y=METRIC, label=name)

fig.show()
# Out:
# /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/ipykernel_89531/786934499.py:7: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
METRIC = 'median'

fig, ax = plt.subplots()

for name, group in res_df.groupby('strain'):
    group.plot(ax=ax, x='Start', y=METRIC, label=name)

fig.show()
# Out:
# /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/ipykernel_89531/39688494.py:8: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
METRIC = 'scores_sum'

fig, ax = plt.subplots()

for name, group in res_df.groupby('strain'):
    group.plot(ax=ax, x='Start', y=METRIC, label=name)

fig.show()
# Out:
# /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/ipykernel_89531/1214877061.py:8: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
METRIC = 'count'

fig, ax = plt.subplots()

for name, group in res_df.groupby('strain'):
    group.plot(ax=ax, x='Start', y=METRIC, label=name)

fig.show()
# Out:
# /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/ipykernel_89531/339707134.py:8: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Plotly plots

# %%
# bin_borders_r = get_bins_borders(1000, 31000)
# bin_ranges_lr = list(zip(bin_borders_r[:-2], bin_borders_r[2:]))

# bins_stats = []
# for strain, zscore_df in z_hunt_results.items():
#     bins_stats.append(process_sequence_zscores(strain, zscore_df, bin_ranges_lr))
# res_lr_df = pd.concat(bins_stats)
# res_lr_df
# Out:
#        strain  Start    End      mean    median  count   scores_sum
# 0     epsilon      0   1000  9.279889  2.542126    999  9270.608727
# 1     epsilon    500   1500  5.275823  0.493970   1012  5339.133130
# 2     epsilon   1000   2000  3.510744  0.368689   1013  3556.383748
# 3     epsilon   1500   2500  3.281756  0.310424   1015  3330.982211
# 4     epsilon   2000   3000  2.734422  0.404224   1013  2769.969180
# ..        ...    ...    ...       ...       ...    ...          ...
# 57  reference  28500  29500  2.887100  0.426489   1012  2921.745388
# 58  reference  29000  30000  3.427785  0.465947    844  2893.050433
# 59  reference  29500  30500  3.198938  0.437340    346  1106.832530
# 60  reference  30000  31000  0.000000  0.000000      0     0.000000
# 61  reference  30500  31500  0.000000  0.000000      0     0.000000
#
# [744 rows x 7 columns]

# %%
METRIC = 'mean'

fig = px.line(res_df, x="Start", y=METRIC, color='strain', title=METRIC)
max_score = res_df[METRIC].max()
for _, row in stats_df[stats_df['P_val_adjusted']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="Blue",
    opacity=0.4,
)
for _, row in stats_df[stats_df['pval']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="LightSkyBlue",
    opacity=0.4,
)

fig.show()

# %%
METRIC = 'median'

fig = px.line(res_df, x="Start", y=METRIC, color='strain', title=METRIC)
max_score = res_df[METRIC].max()
for _, row in stats_df[stats_df['P_val_adjusted']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="Blue",
    opacity=0.4,
)
for _, row in stats_df[stats_df['pval']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="LightSkyBlue",
    opacity=0.4,
)

fig.show()

# %%
METRIC = 'scores_sum'

fig = px.line(res_df, x="Start", y=METRIC, color='strain', title=METRIC)
max_score = res_df[METRIC].max()
for _, row in stats_df[stats_df['P_val_adjusted']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="Blue",
    opacity=0.4,
)
for _, row in stats_df[stats_df['pval']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="LightSkyBlue",
    opacity=0.4,
)

fig.show()

# %%
METRIC = 'count'

fig = px.line(res_df, x="Start", y=METRIC, color='strain', title=METRIC)
max_score = res_df[METRIC].max()
for _, row in stats_df[stats_df['P_val_adjusted']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="Blue",
    opacity=0.4,
)
for _, row in stats_df[stats_df['pval']<=0.05].iterrows():
    fig.add_shape(type="rect",
    x0=row.Start, y0=-0.05, x1=row.End, y1=max_score,
    line=dict(
        color=None,
        width=0,
    ),
    fillcolor="LightSkyBlue",
    opacity=0.4,
)

fig.show()

# %% [markdown]
# # Mutations locations analysis

# %%
from Bio import AlignIO

alignment = AlignIO.read(open("fasta/12_cov2_strains_aligned.fasta"), "fasta")

# %%
REFERENCE_SEQUENE = sequences_df.set_index('strain').loc['reference'].accession
REFERENCE_SEQUENE
# Out:
# 'NC_045512.2'

# %%
aligned_sequences = {seq.name: seq for seq in alignment}
aligned_sequences_df = pd.DataFrame({seq.name: list(seq) for seq in alignment}).T

# %%
START_POS = min([col for col in aligned_sequences_df.columns[:100] if (aligned_sequences_df[col] != '-').all()])
END_POS = max([col for col in aligned_sequences_df.columns[29000:] if (aligned_sequences_df[col] != '-').all()])

START_POS, END_POS
# Out:
# (72, 29818)

# %%
WINDOW = 10
diff_records = []
for position in range(START_POS, END_POS):
    for strain_acc in aligned_sequences_df.index:
        if aligned_sequences_df.loc[strain_acc, position] != aligned_sequences_df.loc[REFERENCE_SEQUENE, position]:
            old_seq = aligned_sequences_df.loc[REFERENCE_SEQUENE, position-WINDOW: position+WINDOW]
            new_seq = aligned_sequences_df.loc[strain_acc, position-WINDOW: position+WINDOW]
            old_zscores = alanrun(''.join(old_seq))
            new_zscores = alanrun(''.join(new_seq))
            old_mean_score = old_zscores['Z-Score'].mean()
            new_mean_score = new_zscores['Z-Score'].mean()
            old_median_score = old_zscores['Z-Score'].median()
            new_median_score = new_zscores['Z-Score'].median()
            
            statistic, pval = kruskal(old_zscores['Z-Score'], new_zscores['Z-Score'])
    
            strain = sequences_df.set_index('accession')['strain'][strain_acc]
            diff_records.append({
                'position': position,
                'position_plot': (position//100)*100,
                'ref_strain': REFERENCE_SEQUENE,
                'strain_acc': strain_acc,
                'strain': strain,
                'ref_base': aligned_sequences_df.loc[REFERENCE_SEQUENE, position],
                'new_base': aligned_sequences_df.loc[strain_acc, position],
                'old_mean_score': old_mean_score,
                'new_mean_score': new_mean_score,
                'mean_diff': old_mean_score - new_mean_score,
                'old_median_score': old_median_score,
                'new_median_score': new_median_score,
                'median_diff': old_median_score - new_median_score,
                'pval': pval,
                'statistic': statistic,

            })
diff_df = pd.DataFrame(diff_records)
# Out:
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5dfivyyz
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5dfivyyz
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5dfivyyz.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5dfivyyz.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5dfivyyz
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpyg28ieku
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpyg28ieku
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpyg28ieku.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpyg28ieku.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpyg28ieku
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmphay4oyjh
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmphay4oyjh
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmphay4oyjh.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmphay4oyjh.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmphay4oyjh
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp8vsfjz0l
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp8vsfjz0l
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp8vsfjz0l.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp8vsfjz0l.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp8vsfjz0l
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp63pl5wtx
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp63pl5wtx
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp63pl5wtx.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp63pl5wtx.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp63pl5wtx
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp7hslugd8
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp7hslugd8
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp7hslugd8.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp7hslugd8.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp7hslugd8
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpo74sesa9
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpo74sesa9
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpo74sesa9.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpo74sesa9.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpo74sesa9
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpajdos8ds
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpajdos8ds
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpajdos8ds.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpajdos8ds.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpajdos8ds
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp0_7w5uy5
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp0_7w5uy5
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp0_7w5uy5.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp0_7w5uy5.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp0_7w5uy5
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpls0zjtt_
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpls0zjtt_
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tm
Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpp9n4m1ln.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpp9n4m1ln
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmper8br7vt
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmper8br7vt
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmper8br7vt.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmper8br7vt.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmper8br7vt
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpuf8ep03t
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpuf8ep03t
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpuf8ep03t.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpuf8ep03t.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpuf8ep03t
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5izykivc
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5izykivc
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5izykivc.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5izykivc.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp5izykivc
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp55ktc9rk
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp55ktc9rk
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp55ktc9rk.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp55ktc9rk.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp55ktc9rk
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpungd2pik
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpungd2pik
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpungd2pik.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpungd2pik.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpungd2pik
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1j3l1s0q
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1j3l1s0q
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1j3l1s0q.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1j3l1s0q.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp1j3l1s0q
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp49e6jfp2
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp49e6jfp2
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp49e6jfp2.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp49e6jfp2.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp49e6jfp2
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvb4q194y
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvb4q194y
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvb4q194y.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvb4q194y.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpvb4q194y
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpr4pu0gzn
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpr4pu0gzn
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpr4pu0gzn.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpr4pu0gzn.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpr4pu0gzn
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp3oholmat
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp3oholmat
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp3oholmat.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp3oholmat.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmp3oholmat
# inputting sequence
# dinucleotides 8
# min/max 6 8
# min/max 6 8
# operating on /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpxv37f7jz
# calculating zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpxv37f7jz
# inputting sequence
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpxv37f7jz.Z-SCORE
#
#  run time=0 sec
# use min/max 6 8
# analyzing_zscore
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpxv37f7jz.Z-SCORE
# opening /var/folders/92/ml61nt355nb1nv82hmrrmz300000gn/T/tmpxv37f7jz
# inputting sequence

# %%
aligned_sequences_df.iloc[:,END_POS-5:]
# Out:
#             29813 29814 29815 29816 29817 29818 29819 29820 29821 29822  ...  \
# MZ169911.1      A     A     T     T     A     A     T     T     T     T  ...
# MZ555270.1      A     A     T     T     A     A     -     -     -     -  ...
# OD920331.1      A     A     T     T     A     A     T     T     T     T  ...
# MZ359841.1      A     A     T     T     A     A     T     T     T     T  ...
# MZ702637.1      A     A     T     T     A     A     T     T     T     T  ...
# MZ275289.1      A     A     T     T     A     A     T     T     T     T  ...
# MW560924.1      A     A     T     T     A     A     T     T     T     T  ...
# MW598419.1      A     A     T     T     A     A     T     T     T     T  ...
# MW883202.1      A     A     T     T     A     A     T     T     T     T  ...
# MW453103.1      A     A     T     T     A     A     T     T     T     T  ...
# MZ681419.1      A     A     T     T     A     A     T     T     T     T  ...
# NC_045512.2     A     A     T     T     A     A     T     T     T     T  ...
#
#             29893 29894 29895 29896 29897 29898 29899 29900 29901 29902
# MZ169911.1      A     A     A     A     A     A     A     A     A     A
# MZ555270.1      -     -     -     -     -     -     -     -     -     -
# OD920331.1      -     -     -     -     -     -     -     -     -     -
# MZ359841.1      -     -     -     -     -     -     -     -     -     -
# MZ702637.1      -     -     -     -     -     -     -     -     -     -
# MZ275289.1      -     -     -     -     -     -     -     -     -     -
# MW560924.1      -     -     -     -     -     -     -     -     -     -
# MW598419.1      A     A     A     A     A     A     A     A     A     A
# MW883202.1      -     -     -     -     -     -     -     -     -     -
# MW453103.1      -     -     -     -     -     -     -     -     -     -
# MZ681419.1      -     -     -     -     -     -     -     -     -     -
# NC_045512.2     A     A     A     A     A     A     A     A     A     A
#
# [12 rows x 90 columns]

# %%
diff_df
# Out:
#      position  position_plot   ref_strain  strain_acc strain ref_base  \
# 0          75              0  NC_045512.2  MZ169911.1  gamma        T
# 1          76              0  NC_045512.2  MZ169911.1  gamma        T
# 2          77              0  NC_045512.2  MZ169911.1  gamma        T
# 3          78              0  NC_045512.2  MZ169911.1  gamma        A
# 4          82              0  NC_045512.2  MZ169911.1  gamma        T
# ..        ...            ...          ...         ...    ...      ...
# 517     29771          29700  NC_045512.2  MW560924.1    eta        T
# 518     29772          29700  NC_045512.2  MW560924.1    eta        G
# 519     29773          29700  NC_045512.2  MW560924.1    eta        C
# 520     29774          29700  NC_045512.2  MW560924.1    eta        T
# 521     29775          29700  NC_045512.2  MW560924.1    eta        A
#
#     new_base  old_mean_score  new_mean_score  mean_diff  old_median_score  \
# 0          A        0.245685        1.499158  -1.253473          0.214908
# 1          A        0.206859        1.432560  -1.225701          0.202601
# 2          A        0.760510        2.507290  -1.746780          0.311375
# 3          C        1.872064        4.056529  -2.184465          2.306021
# 4          C        4.001981        6.739759  -2.737778          4.026194
# ..       ...             ...             ...        ...               ...
# 517        -        0.295414        0.236403   0.059011          0.285847
# 518        -        0.616128        0.295931   0.320198          0.317268
# 519        -        4.541935        5.911505  -1.369570          3.994129
# 520        -        0.309460        0.365703  -0.056243          0.329925
# 521        -        0.240048        0.361517  -0.121469          0.224803
#
#      new_median_score  median_diff          pval  statistic
# 0            0.497103    -0.282195  1.649882e-06  22.964879
# 1            2.047895    -1.845294  4.565532e-07  25.439171
# 2            2.509584    -2.198209  1.348278e-05  18.940943
# 3            3.719740    -1.413719  2.871242e-03   8.887534
# 4            5.345663    -1.319469  1.046304e-01   2.633507
# ..                ...          ...           ...        ...
# 517          0.247968     0.037879  1.441572e-01   2.133012
# 518          0.298175     0.019093  5.774166e-01   0.310430
# 519          6.245526    -2.251397  1.182386e-01   2.440500
# 520          0.368266    -0.038341  1.294977e-01   2.298515
# 521          0.339157    -0.114354  2.694482e-03   9.003601
#
# [522 rows x 15 columns]

# %%
(diff_df['old_mean_score'] - diff_df['new_mean_score']).plot(kind='hist', bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
(diff_df['old_mean_score'] - diff_df['new_mean_score']).plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from statsmodels.graphics.gofplots import qqplot

qqplot(diff_df['old_mean_score'] - diff_df['new_mean_score'])
# Out:
# /Users/alexandershein/miniconda3/envs/z_cov/lib/python3.9/site-packages/statsmodels/graphics/gofplots.py:993: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.

# %%
(diff_df['old_mean_score'] - diff_df['new_mean_score']).describe()
# Out:
# count    492.000000
# mean       0.934632
# std        7.878425
# min      -39.500225
# 25%       -0.057598
# 50%        0.121533
# 75%        0.727131
# max      136.856521
# dtype: float64

# %%
diff_df['mean_diff'] = diff_df['old_mean_score'] - diff_df['new_mean_score']
diff_df['position_plot'] = (diff_df['position'] // 100) * 100
plot_df = diff_df.groupby('position_plot').agg({'mean_diff': 'sum', 'strain': 'first', }).reset_index(drop=False)
# diff_df.plot(kind='bar', x='position_plot', y='mean_diff', title='strain', )
fig = px.bar(plot_df, x="position_plot", y='mean_diff', color='strain', title='Mean diff from reference')
fig.show()

# %%
# for strain, group in diff_df.groupby('strain'):
#     group.plot(kind='bar', x='position', y='mean_diff', title=strain, )
# #     group.plot(kind='kde', x='position', y='mean_diff', title=strain, )
#     plt.show()
